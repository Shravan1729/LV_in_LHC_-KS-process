# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
signal_df_4 = pd.read_csv("signal/run_04.csv")
signal_df_11 = pd.read_csv("signal/run_11.csv")
bkg_df    = pd.read_csv("BKG/ttbar.csv")
ks_df_11     = pd.read_csv("KS/run_11.csv")
ks_df_4     = pd.read_csv("KS/run_04.csv")

signal_df_4['label'] = 'signal'
signal_df_11['label'] = 'signal'
ks_df_4['label'] = 'ks'
ks_df_11['label'] = 'ks'
bkg_df['label'] = 'bkg'
## Try adding all the benchmarks

# %%
signal_df.head()
# Out:
#      pt_mu1    pt_mu2    pt_fjt     M_fjt      S_T        MET  DR_fjt_mu1  \
# 0  1165.920   784.461  1889.160  126.4850  3831.72   127.2190     3.51699
# 1   508.733   161.062   560.223   80.7338  1284.61    46.0013     4.69172
# 2  1797.690  1388.830   301.418   80.4875  3547.43   715.8940     2.82461
# 3  1374.240   354.839  1998.310  101.1760  4014.12   309.7180     3.08569
# 4  2664.040   543.212  1035.700   94.4386  4462.22  1070.3200     3.74631
#
#    DR_fjt_mu2  DR_mu1_mu2   label
# 0    3.167450    0.970498  signal
# 1    4.955060    1.260910  signal
# 2    3.637520    3.076580  signal
# 3    2.168140    1.690160  signal
# 4    0.815677    3.141710  signal

# %%
bkg_df.head()
# Out:
#      pt_mu1    pt_mu2    pt_fjt     M_fjt      S_T       MET  DR_fjt_mu1  \
# 0  142.1580  123.1310   85.9231  10.58120  408.315   9.71531     2.73356
# 1   88.8585   35.8508  111.5020  18.28230  328.059   7.89233     3.73447
# 2   47.8859   30.5145   66.9824  20.60890  264.406  38.70030     2.15071
# 3  168.1530   68.5559   78.4107   8.15526  390.382  38.70840     2.91830
# 4  187.7840  140.9250  210.0020  19.80510  771.505  56.87770     3.02043
#
#    DR_fjt_mu2  DR_mu1_mu2 label
# 0    1.217270    2.879330   bkg
# 1    3.056370    0.919179   bkg
# 2    1.546700    1.132390   bkg
# 3    0.640573    2.947300   bkg
# 4    0.778432    2.532270   bkg

# %%
ks_df_4.head()
# Out:
#      pt_mu1   pt_mu2   pt_fjt     M_fjt      S_T       MET  DR_fjt_mu1  \
# 0   793.720  634.435  574.043   71.0894  2251.70  208.7050     2.41269
# 1   644.064  291.300  560.580  156.5280  1771.59   35.1372     3.25499
# 2  1111.990  181.530  658.606  118.8360  2137.03  248.8810     3.15866
# 3   481.659  217.147  258.888   30.6277  1143.64   28.1338     3.44848
# 4   703.057  522.415  200.009   25.6084  1522.91   30.5338     2.95391
#
#    DR_fjt_mu2  DR_mu1_mu2 label
# 0    1.484650     2.54828    ks
# 1    1.139390     2.67737    ks
# 2    1.507670     2.02298    ks
# 3    1.032160     3.97749    ks
# 4    0.924663     3.25179    ks

# %%
ks_df_11.head()
# Out:
#     pt_mu1   pt_mu2    pt_fjt     M_fjt      S_T       MET  DR_fjt_mu1  \
# 0  732.867  449.296   822.989   86.2922  2727.36  180.9680     2.00736
# 1  861.083  837.082   804.892   68.7447  3027.69   92.9055     2.63422
# 2  887.832  531.811  1329.420  106.7270  3879.07   97.1038     3.35691
# 3  573.119  558.308   882.870   65.6946  3020.95  103.6600     1.50645
# 4  914.827  437.760  1465.330   97.7484  4296.81   29.3353     2.01032
#
#    DR_fjt_mu2  DR_mu1_mu2 label
# 0    2.331110     3.38789    ks
# 1    2.682540     2.60748    ks
# 2    0.821311     3.19804    ks
# 3    3.138560     2.27821    ks
# 4    2.505670     1.83545    ks

# %%
mu1_11 = ks_df_11['pt_mu1']
mu2_11 = ks_df_11['pt_mu2']

# %%
mu1_4 = ks_df_4['pt_mu1']
mu2_4 = ks_df_4['pt_mu2']

# %%
plt.hist(mu1_11, bins = 100, alpha = 0.5, label = 'pt_mu1')
plt.hist(mu2_11, bins = 100, alpha = 0.5, label = 'pt_mu2')
plt.title('benchmark11(MW_5TeV_MN_4.5TeV)')
plt.legend()
plt.savefig('KS/Plots_KS/benchmark11.png')

# %%
plt.hist(mu1_4, bins = 100, alpha = 0.5, label = 'pt_mu1')
plt.hist(mu2_4, bins = 100, alpha = 0.5, label = 'pt_mu2')
plt.title('benchmark4(MW_5TeV_MN_4.5TeV)')
plt.legend()
plt.savefig('KS/Plots_KS/benchmark4.png')

# %%
def pT_dist(n):
    ks = pd.read_csv(f"KS/run_{n}.csv")
    ks['label'] = 'ks'
    mu1 = ks['pt_mu1']
    mu2 = ks['pt_mu2']
    plt.hist(mu1, bins = 100, alpha = 0.5, label = 'pt_mu1')
    plt.hist(mu2, bins = 100, alpha = 0.5, label = 'pt_mu2')
    plt.title(f'benchmark{n}(MW_5TeV_MN_4.5TeV)')
    plt.legend()
    plt.savefig('KS/Plots_KS/benchmark{n}.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the benchmark summary once
summary_df = pd.read_csv("BP.csv", index_col="run_name")

def pT_dist(n):
    run_name = f"run_{int(n):02d}"
    
    # Load KS CSV for this run
    ks = pd.read_csv(f"KS/{run_name}.csv")
    ks['label'] = 'ks'
    
    mu1 = ks['pt_mu1']
    mu2 = ks['pt_mu2']

    # Extract MW and MN from the summary table
    MW = summary_df.loc[run_name, 'mass_MWp_GeV'] / 1000
    MN = summary_df.loc[run_name, 'mass_MNR_GeV'] / 1000

    # Plot
    plt.figure(figsize=(8, 5))
    plt.hist(mu1, bins=100, alpha=0.5, label='pt_mu1')
    plt.hist(mu2, bins=100, alpha=0.5, label='pt_mu2')
    plt.title(f'benchmark{n}(MW_{MW:.1f}TeV_MN_{MN:.1f}TeV)')
    plt.legend()
    plt.tight_layout()
    plt.savefig(f'KS/Plots_KS/benchmark{n}.png')
    plt.show()
    plt.close()

# %%
pT_dist('06')

# %%
print(f"Number of signal events: {len(signal_df_4)}")
print(f"Nomber of bkg events: {len(bkg_df)}")
print(f"Nomber of ks events: {len(ks_df_4)}")
# signal_df.describe()
# Out:
# Number of signal events: 7038
# Nomber of bkg events: 23179
# Nomber of ks events: 6188

# %%
print(f"Number of signal events: {len(signal_df_11)}")
print(f"Nomber of bkg events: {len(bkg_df)}")
print(f"Nomber of ks events: {len(ks_df_11)}")
# Out:
# Number of signal events: 5425
# Nomber of bkg events: 23179
# Nomber of ks events: 6021

# %%
df_sb = pd.concat([signal_df_4, bkg_df], ignore_index=True)
df_sk = pd.concat([signal_df_4, ks_df_4], ignore_index=True)

features = [f for f in df_sk.columns if f not in ['label', 'benchmark']]

# %%
for col in features[:12]:
    plt.figure(figsize=(6, 4))
    plt.hist(df_sk[df_sk['label'] == 'signal'][col], bins=50, alpha=0.5, label='Signal', color='r', density=True)
    plt.hist(df_sk[df_sk['label'] == 'ks'][col], bins=50, alpha=0.5, label='KS', color='b', density=True)
    plt.xlabel(col)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Simple Classifier

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_auc_score, roc_curve
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Input
from tensorflow.keras import layers
# Out:
# 2025-07-12 14:40:28.760479: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752311428.811624    9386 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752311428.826700    9386 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1752311428.934047    9386 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1752311428.934077    9386 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1752311428.934078    9386 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1752311428.934080    9386 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-07-12 14:40:28.948589: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# df_binary = df_sk[df_sk['label'].isin(['signal', 'ks'])].copy()
# df_binary['y'] = (df_binary['label'] == 'signal').astype(int)

# X = df_binary[features].values
# y = df_binary['y'].values

# # Train-test split
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y, test_size=0.3, random_state=42, stratify=y
# )
# # Standardize

# scaler = StandardScaler()
# X_train = scaler.fit_transform(X_train)
# X_test = scaler.transform(X_test)
# #Model
# model = keras.Sequential([
#     keras.Input(shape=(X_train.shape[1],)),
#     layers.Dense(32, activation='relu'),
#     layers.Dense(1, activation='sigmoid')
# ])
# ##Exercise : Change the model and try to avoid overfitting

# #Compilation
# model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# model.summary()

# history = model.fit(
#     X_train, y_train,
#     epochs=10,
#     batch_size=64,
#     validation_split=0.2,
#     verbose=1
# )
# Out:
# I0000 00:00:1752305601.810350   13152 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2554 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 32)             │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 353 (1.38 KB)
#  Trainable params: 353 (1.38 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1752305603.074323   19641 service.cc:152] XLA service 0x72050c0033d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1752305603.074346   19641 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce GTX 1650, Compute Capability 7.5
# 2025-07-12 13:03:23.092357: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# E0000 00:00:1752305603.265324   19641 cuda_dnn.cc:522] Loaded runtime CuDNN library: 9.1.0 but source was compiled with: 9.3.0.  CuDNN library needs to have matching major version and equal or higher minor version. If using a binary install, upgrade your CuDNN library.  If building from sources, make sure the library loaded at runtime is compatible with the version specified during compile configuration.
# E0000 00:00:1752305603.279355   19641 cuda_dnn.cc:522] Loaded runtime CuDNN library: 9.1.0 but source was compiled with: 9.3.0.  CuDNN library needs to have matching major version and equal or higher minor version. If using a binary install, upgrade your CuDNN library.  If building from sources, make sure the library loaded at runtime is compatible with the version specified during compile configuration.
# 2025-07-12 13:03:23.282910: W tensorflow/core/framework/op_kernel.cc:1857] OP_REQUIRES failed at xla_ops.cc:591 : FAILED_PRECONDITION: DNN library initialization failed. Look at the errors above for more details.
# 2025-07-12 13:03:23.282954: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: FAILED_PRECONDITION: DNN library initialization failed. Look at the errors above for more details.
# 	 [[{{node StatefulPartitionedCall}}]]
# ---------------------------------------------------------------------------
# FailedPreconditionError                   Traceback (most recent call last)
# Cell In[21], line 28
#      25 model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#      26 model.summary()
# ---> 28 history = model.fit(
#      29     X_train, y_train,
#      30     epochs=10,
#      31     batch_size=64,
#      32     validation_split=0.2,
#      33     verbose=1
#      34 )
#
# File ~/miniconda3/envs/temporary/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/miniconda3/envs/temporary/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# FailedPreconditionError: Graph execution error:
#
# Detected at node StatefulPartitionedCall defined at (most recent call last):
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/runpy.py", line 87, in _run_code
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/ipykernel_launcher.py", line 18, in <module>
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 739, in start
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 205, in start
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/asyncio/events.py", line 80, in _run
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3048, in run_cell
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3103, in _run_cell
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3308, in run_cell_async
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3490, in run_ast_nodes
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3550, in run_code
#
#   File "/tmp/ipykernel_13152/1795819520.py", line 28, in <module>
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/keras/src/backend/tensorflow/trainer.py", line 377, in fit
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/keras/src/backend/tensorflow/trainer.py", line 220, in function
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/keras/src/backend/tensorflow/trainer.py", line 133, in multi_step_on_iterator
#
# DNN library initialization failed. Look at the errors above for more details.
# 	 [[{{node StatefulPartitionedCall}}]] [Op:__inference_multi_step_on_iterator_1089]

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow import keras
from tensorflow.keras import layers

def train_binary_classifier(df_sk, features, epochs=10, batch_size=64):
    """
    Trains a binary classifier to distinguish 'signal' from 'ks'.

    Args:
        df_sk (pd.DataFrame): Original DataFrame.
        features (list): List of feature column names.
        epochs (int): Number of training epochs.
        batch_size (int): Batch size for training.

    Returns:
        model: Trained Keras model.
        history: Training history object.
    """

    # Filter and encode
    df_binary = df_sk[df_sk['label'].isin(['signal', 'ks'])].copy()
    df_binary['y'] = (df_binary['label'] == 'signal').astype(int)

    # Extract X and y
    X = df_binary[features].values
    y = df_binary['y'].values

    # Train-test split
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.3, random_state=42, stratify=y
    )

    # Standardize
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    # Define model (can be modified to reduce overfitting)
    model = keras.Sequential([
        keras.Input(shape=(X_train.shape[1],)),
        layers.Dense(64, activation='relu'),
        layers.Dropout(0.3),
        layers.Dense(32, activation='relu'),
        layers.Dropout(0.2),
        layers.Dense(1, activation='sigmoid')
    ])

    # Compile
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    # Train
    history = model.fit(
        X_train, y_train,
        validation_split=0.2,
        epochs=epochs,
        batch_size=batch_size,
        verbose=1
    )

    return model, history

# %%
df_sb_11 = pd.concat([signal_df_11, bkg_df], ignore_index=True)
df_sk_11 = pd.concat([signal_df_11, ks_df_11], ignore_index=True)

features = [f for f in df_sk_11.columns if f not in ['label', 'benchmark']]

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

model, history = train_binary_classifier(df_sk_11, features)
# Out:
# Epoch 1/10
# E0000 00:00:1752306236.439429   19642 cuda_dnn.cc:522] Loaded runtime CuDNN library: 9.1.0 but source was compiled with: 9.3.0.  CuDNN library needs to have matching major version and equal or higher minor version. If using a binary install, upgrade your CuDNN library.  If building from sources, make sure the library loaded at runtime is compatible with the version specified during compile configuration.
# E0000 00:00:1752306236.516286   19642 cuda_dnn.cc:522] Loaded runtime CuDNN library: 9.1.0 but source was compiled with: 9.3.0.  CuDNN library needs to have matching major version and equal or higher minor version. If using a binary install, upgrade your CuDNN library.  If building from sources, make sure the library loaded at runtime is compatible with the version specified during compile configuration.
# 2025-07-12 13:13:56.521058: W tensorflow/core/framework/op_kernel.cc:1857] OP_REQUIRES failed at xla_ops.cc:591 : FAILED_PRECONDITION: DNN library initialization failed. Look at the errors above for more details.
# 2025-07-12 13:13:56.521102: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: FAILED_PRECONDITION: DNN library initialization failed. Look at the errors above for more details.
# 	 [[{{node StatefulPartitionedCall}}]]
# ---------------------------------------------------------------------------
# FailedPreconditionError                   Traceback (most recent call last)
# Cell In[27], line 7
#       4 from tensorflow import keras
#       5 from tensorflow.keras import layers
# ----> 7 model, history = train_binary_classifier(df_sk_11, features)
#
# Cell In[23], line 55, in train_binary_classifier(df_sk, features, epochs, batch_size)
#      52 model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#      54 # Train
# ---> 55 history = model.fit(
#      56     X_train, y_train,
#      57     validation_split=0.2,
#      58     epochs=epochs,
#      59     batch_size=batch_size,
#      60     verbose=1
#      61 )
#      63 return model, history
#
# File ~/miniconda3/envs/temporary/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/miniconda3/envs/temporary/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# FailedPreconditionError: Graph execution error:
#
# Detected at node StatefulPartitionedCall defined at (most recent call last):
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/runpy.py", line 87, in _run_code
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/ipykernel_launcher.py", line 18, in <module>
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 739, in start
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 205, in start
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/asyncio/events.py", line 80, in _run
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3048, in run_cell
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3103, in _run_cell
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3308, in run_cell_async
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3490, in run_ast_nodes
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3550, in run_code
#
#   File "/tmp/ipykernel_13152/1846162637.py", line 7, in <module>
#
#   File "/tmp/ipykernel_13152/3946875512.py", line 55, in train_binary_classifier
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/keras/src/backend/tensorflow/trainer.py", line 377, in fit
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/keras/src/backend/tensorflow/trainer.py", line 220, in function
#
#   File "/home/bapi_cms/miniconda3/envs/temporary/lib/python3.9/site-packages/keras/src/backend/tensorflow/trainer.py", line 133, in multi_step_on_iterator
#
# DNN library initialization failed. Look at the errors above for more details.
# 	 [[{{node StatefulPartitionedCall}}]] [Op:__inference_multi_step_on_iterator_5808]

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np

# Define your DNN model
class SimpleDNN(nn.Module):
    def __init__(self, input_dim):
        super(SimpleDNN, self).__init__()
        self.fc1 = nn.Linear(input_dim, 64)
        self.fc2 = nn.Linear(64, 64)
        self.out = nn.Linear(64, 1)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.out(x)
        return x

# %%
def train_pytorch_dnn(df_sk, features, epochs=10, batch_size=64, lr=1e-3, device='cpu'):
    df_binary = df_sk[df_sk['label'].isin(['signal', 'ks'])].copy()
    df_binary['y'] = (df_binary['label'] == 'signal').astype(int)

    X = df_binary[features].values
    y = df_binary['y'].values.reshape(-1, 1)

    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.3, random_state=42, stratify=y
    )

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
    y_train_tensor = torch.tensor(y_train, dtype=torch.float32)
    X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
    y_test_tensor = torch.tensor(y_test, dtype=torch.float32)

    train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

    model = SimpleDNN(input_dim=X_train.shape[1]).to(device)
    criterion = nn.BCEWithLogitsLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr)

    history = {'loss': [], 'accuracy': []}

    model.train()
    for epoch in range(epochs):
        total_loss = 0.0
        correct = 0
        total = 0

        for batch_X, batch_y in train_loader:
            batch_X, batch_y = batch_X.to(device), batch_y.to(device)
            optimizer.zero_grad()
            outputs = model(batch_X)
            loss = criterion(outputs, batch_y)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

            preds = (torch.sigmoid(outputs) > 0.5).float()
            correct += (preds == batch_y).sum().item()
            total += batch_y.size(0)

        acc = correct / total
        history['loss'].append(total_loss)
        history['accuracy'].append(acc)
        print(f"Epoch {epoch+1}/{epochs} - Loss: {total_loss:.4f} - Acc: {acc:.4f}")

    return model, scaler, X_test_tensor, y_test_tensor, history

# %%
model, scalar, X_test_tensor, y_test_tensor, history = train_pytorch_dnn(df_sk_11, features, epochs=280)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 model, scalar, X_test_tensor, y_test_tensor, history = train_pytorch_dnn(df_sk_11, features, epochs=280)
#
# NameError: name 'df_sk_11' is not defined

# %%
# # Predict
# y_pred_prob = model.predict(X_test).ravel()
# y_pred = (y_pred_prob > 0.5).astype(int)

# # print("y_test shape:", y_test.shape)
# # print("y_pred_prob shape:", y_pred_prob.shape)

# # Accuracy Curve
# plt.figure(figsize=(6, 4))
# plt.plot(history.history['accuracy'], label='Train Acc')
# plt.plot(history.history['val_accuracy'], label='Val Acc')
# plt.legend()
# plt.show()

# # Loss Curve
# plt.figure(figsize=(6, 4))
# plt.plot(history.history['loss'], label='Train Loss')
# plt.plot(history.history['val_loss'], label='Val Loss')
# plt.legend()
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 2
#       1 # Predict
# ----> 2 y_pred_prob = model.predict(X_test).ravel()
#       3 y_pred = (y_pred_prob > 0.5).astype(int)
#       5 # print("y_test shape:", y_test.shape)
#       6 # print("y_pred_prob shape:", y_pred_prob.shape)
#       7
#       8 # Accuracy Curve
#
# File ~/miniconda3/envs/temporary/lib/python3.9/site-packages/torch/nn/modules/module.py:1931, in Module.__getattr__(self, name)
#    1929     if name in modules:
#    1930         return modules[name]
# -> 1931 raise AttributeError(
#    1932     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1933 )
#
# AttributeError: 'SimpleDNN' object has no attribute 'predict'

# %%
import matplotlib.pyplot as plt

# Train and get history
model, scaler, X_test_tensor, y_test_tensor, history = train_pytorch_dnn(df_sk_11, features, epochs=20)

# Predict
model.eval()
with torch.no_grad():
    logits = model(X_test_tensor)
    probs = torch.sigmoid(logits)
    y_pred = (probs > 0.5).float().numpy().ravel()
    y_true = y_test_tensor.numpy().ravel()

# Accuracy
accuracy = (y_pred == y_true).mean()
print(f"Test Accuracy: {accuracy:.4f}")

# Plot Accuracy Curve
plt.figure(figsize=(6, 4))
plt.plot(history['accuracy'], label='Train Acc')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Training Accuracy")
plt.grid()
plt.show()

# Plot Loss Curve
plt.figure(figsize=(6, 4))
plt.plot(history['loss'], label='Train Loss')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.title("Training Loss")
plt.grid()
plt.show()
# Out:
# Epoch 1/20 - Loss: 54.0558 - Acc: 0.8414
# Epoch 2/20 - Loss: 27.9167 - Acc: 0.9207
# Epoch 3/20 - Loss: 24.9727 - Acc: 0.9289
# Epoch 4/20 - Loss: 24.1261 - Acc: 0.9307
# Epoch 5/20 - Loss: 23.4539 - Acc: 0.9329
# Epoch 6/20 - Loss: 23.1058 - Acc: 0.9316
# Epoch 7/20 - Loss: 22.8280 - Acc: 0.9347
# Epoch 8/20 - Loss: 22.4505 - Acc: 0.9348
# Epoch 9/20 - Loss: 22.7351 - Acc: 0.9355
# Epoch 10/20 - Loss: 22.0240 - Acc: 0.9365
# Epoch 11/20 - Loss: 22.0983 - Acc: 0.9361
# Epoch 12/20 - Loss: 21.5845 - Acc: 0.9358
# Epoch 13/20 - Loss: 21.6541 - Acc: 0.9380
# Epoch 14/20 - Loss: 21.5640 - Acc: 0.9392
# Epoch 15/20 - Loss: 21.1792 - Acc: 0.9382
# Epoch 16/20 - Loss: 20.9913 - Acc: 0.9375
# Epoch 17/20 - Loss: 20.7515 - Acc: 0.9393
# Epoch 18/20 - Loss: 20.6903 - Acc: 0.9393
# Epoch 19/20 - Loss: 20.7546 - Acc: 0.9402
# Epoch 20/20 - Loss: 20.5917 - Acc: 0.9380
# Test Accuracy: 0.9336

# %%
from torchinfo import summary

# Example input dimension
input_dim = 8  # <-- change this according to your dataset

# Instantiate model
model = SimpleDNN(input_dim=input_dim)

# Print summary (for batch size = 64)
summary(model, input_size=(64, input_dim))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# SimpleDNN                                [64, 1]                   --
# ├─Linear: 1-1                            [64, 64]                  576
# ├─Linear: 1-2                            [64, 64]                  4,160
# ├─Linear: 1-3                            [64, 1]                   65
# ==========================================================================================
# Total params: 4,801
# Trainable params: 4,801
# Non-trainable params: 0
# Total mult-adds (M): 0.31
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.07
# Params size (MB): 0.02
# Estimated Total Size (MB): 0.09
# ==========================================================================================

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt
# Predict probabilities
with torch.no_grad():
    logits = model(X_test_tensor)
    y_pred_prob = torch.sigmoid(logits).cpu().numpy().ravel()  # probabilities
    y_pred = (y_pred_prob > 0.5).astype(int)                   # binary predictions
    y_true = y_test_tensor.cpu().numpy().ravel()

fpr, tpr, _ = roc_curve(y_true, y_pred_prob)
auc_val = roc_auc_score(y_true, y_pred_prob)

plt.figure(figsize=(6, 4))
plt.plot(fpr, tpr, label=f"AUC = {auc_val:.3f}", color='darkorange')
plt.plot([0, 1], [0, 1], 'k--', label='Random')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.grid()
plt.show()

# %%
df_scores = pd.DataFrame({
    'score': y_pred_prob,
    'true_label': y_test
})
df_scores['class'] = df_scores['true_label'].map({1: 'Signal', 0: 'KS'})  # or 'BKG'

plt.figure(figsize=(7, 4))
sns.histplot(data=df_scores, x='score', hue='class', bins=50, stat='density',
             common_norm=False, alpha=0.6, palette='Set1')
plt.xlabel("Predicted Score")
plt.show()
